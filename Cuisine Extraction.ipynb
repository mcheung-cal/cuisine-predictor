# %%
import pandas as pd
import collections
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import numpy as np
import regex as re

from google.colab import drive, files
drive.mount('/drive')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
recipes = pd.read_csv('/drive/My Drive/Data144/RAW_recipes.csv', low_memory = False)

# %%
#recipes = recipes.iloc[:50000]
recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# ...

# %%
recipes["tags"] = [string.strip("][").replace("'", '').split(', ') for string in recipes["tags"]]

# %%
cuisines = pd.read_csv('/drive/My Drive/Data144/cuisines.csv', low_memory = False)

# %%
cuisines.head()
# Out:
#    cuisines
# 0     afgan
# 1   african
# 2  algerian
# 3  american
# 4      arab

# %%
cuisines_list = cuisines['cuisines'].to_list()

# %%
def cuisine_extractor(column):
  cuisine_col = []
  for x in column:
    yes = 0
    for y in cuisines_list:
      if yes == 0:
        if y in x:
          yes = 1
          cuisine_col += [y]
    if yes == 0:
      cuisine_col += ['n/a']
  return cuisine_col

# %%
cuisine_col = cuisine_extractor(recipes['tags'])

# %%
recipes['cuisine'] = cuisine_col
recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  [60-minutes-or-less, time-to-make, course, mai...
# 1  [30-minutes-or-less, time-to-make, course, mai...
# 2  [time-to-make, course, preparation, main-dish,...
# 3  [60-minutes-or-less, time-to-make, course, mai...
# 4  [weeknight, time-to-make, course, main-ingredi...
#
#                                     nutrition  n_steps  \
# ...

# %%
missing_cuisine = recipes[recipes['cuisine'] == 'n/a'].index
recipes.drop(missing_cuisine, inplace=True)
len(recipes)
# Out:
# 74248

# %%
recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 4          amish  tomato ketchup  for canning   44061      190
# 5                     apple a day  milk shake    5289        0
# 6                       aww  marinated olives   25274       15
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 4           41706  2002-10-25
# 5            1533  1999-12-06
# 6           21730  2002-04-14
#
#                                                 tags  \
# 0  [60-minutes-or-less, time-to-make, course, mai...
# 1  [30-minutes-or-less, time-to-make, course, mai...
# 4  [weeknight, time-to-make, course, main-ingredi...
# 5  [15-minutes-or-less, time-to-make, course, mai...
# 6  [15-minutes-or-less, time-to-make, course, mai...
#
#                                    nutrition  n_steps  \
# ...

# %%
recipes.to_csv('recipes_cuisine.csv', index=False)
